# %%
print("Hellow World")
# Out:
# Hellow World

# %%
a = 10
b = 5
print("addition:",a+b,"subtraction:",a-b,"division:",a/b,"multipication:",a*b)
# Out:
# addition: 15 subtraction: 5 division: 2.0 multipication: 50

# %%
x = 25 
y = 4 
print("floor Division:",x//y,"modulus:",x%y)
# Out:
# floor Division: 6 modulus: 1

# %%
num = 12 
print("square",num**2,"cube",num**3)
# Out:
# square 144 cube 1728

# %%
len = 15
bre = 6
print("area of rectangle:",len*bre)
# Out:
# area of rectangle: 90

# %%
radius = 5
pi = 3.14
print("area of circle:",pi*radius*radius)
# Out:
# area of circle: 78.5

# %%
price = 120
quantity = 8
print("total cost of 8 books is:",price*quantity)
# Out:
# total cost of 8 books is: 960

# %%
marks1 = 70
marks2 = 80
marks3 = 90
print("total marks:",marks1+marks2+marks3 ,"average of marks:",240/3)
# Out:
# total marks: 240 average of marks: 80.0

# %%
a = 15
b = 10
print(a>b,a<b,a==b,a!=b)
# Out:
# True False False True

# %%
x = 12
y = 20
print(x>=y,x<=y)
# Out:
# False True

# %%
a = 10
b = 5
c = 2
print(a+b*c)
# Out:
# 20

# %%
a = 8
b = 4
print((a+b)*(a-b))
# Out:
# 48

# %%
num1 = 10 
num2 = 20
print(num1<num2 and num2>15)
# Out:
# True

# %%
x = 5 
y = 10 
print(x>y or y>x)
# Out:
# True

# %%
a = 20
print("initial value:",a)
a = a+5
print("after+5:",a)
a = a-3
print("after-3",a)
a = a*2
print("after*2",a)
# Out:
# initial value: 20
# after+5: 25
# after-3 22
# after*2 44

# %%
num = 50 
div = 6
print(num/div)
# Out:
# 8.333333333333334

# %%
dis = 120
time = 4 
speed = dis / time
print("speed :",speed)
# Out:
# speed : 30.0

# %%
a = 6
b = 3
c = 2
sum = a*b+c
print("result:",sum)
# Out:
# result: 20

# %%
num1 = 25
num2 = 5
r1 = num1/num2
r2 = num1*num2
print(r1+r2)
# Out:
# 130.0

# %%
p = 8 
q = 4
print(p>q and p!=q)
# Out:
# True
